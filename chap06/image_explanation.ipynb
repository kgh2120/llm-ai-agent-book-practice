# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

client = OpenAI(api_key=api_key)

messages = [
    {
        "role" : "user",
        "content" : [
            {"type" : "text", "text" : "이 이미지에 대해서 설명해 주세요."},
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : "https://images.unsplash.com/photo-1744922679352-98dc9f5ddeb6?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.1.0&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D"
                }
            }
        ]
    }
]

response = client.chat.completions.create(
    model = "gpt-4o",
    messages=messages
)

response
# Out:
# ChatCompletion(id='chatcmpl-BgQ5wmyLwZYVHnHJUSkZkpuEk2pBH', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='이미지에는 젊은 사람이 실내에서 책상 앞에 앉아 있습니다. 흰 셔츠를 입고 있으며, 손에는 작은 모형 풍력 터빈이 있습니다. 책상 위에는 노트북과 커피 컵, 식물이 놓여 있습니다. 창문 밖으로는 흐릿한 배경이 보입니다. 밝은 자연광이 실내를 비추고 있습니다.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))], created=1749449784, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_a288987b44', usage=CompletionUsage(completion_tokens=87, prompt_tokens=1120, total_tokens=1207, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
import base64

def encode_image(image_path):
    with open(image_path, 'rb') as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")
    
image_path = './image/mart-image.jpg'

base64_image = encode_image(image_path)

print(base64_image)
# Out:
# ...

# %%
messages = [
    {
        "role" : "user",
        "content" : [
            {"type" : "text", "text" : "이 이미지에 대해 설명해 주세요."},
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : f"data:image/jpeg;base64,{base64_image}",
                }
            }
        ]
     
     }
]

response = client.chat.completions.create(
    model='gpt-4o',
    messages=messages
)

response.choices[0].message.content
# Out:
# '이 이미지는 롯데슈퍼의 "롯데 레드페스티벌" 할인 행사 포스터입니다. 행사는 2025년 6월 5일부터 6월 25일까지 진행됩니다. 주요 할인 품목은 다음과 같습니다:\n\n- 수박: 전품목 1만원 할인\n- 한우 등심: 최대 50% 할인\n- 돼지고기 삼겹살/목심: 62% 할인, 985원\n- 인기 스낵 12종: 균일가 990원\n- 인기 바류 아이스크림 25종: 균일가 500원\n\n또한, 5만원 이상 구매 시 5,000원 할인 쿠폰과 롯데마트 ZETTA 앱 회원 혜택 등 다양한 추가 혜택도 제공됩니다.'

# %%
sulbing_base64 = encode_image("./image/sulbing-myeongdong-1.jpg")
blindspot_base64 = encode_image('./image/blind-spot.jpg')

messages = [
    {
        "role" : "user",
        "content" : [
            {"type" : "text", "text" : "두 카페의 차이점을 설명해 주세요."},
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : f"data:image/jpeg;base64,{sulbing_base64}"
                }
            },
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : f"data:image/jpeg;base64,{blindspot_base64}"
                }
            }
        ]
    }
]

response = client.chat.completions.create(
    model='gpt-4o',
    messages=messages
)

response.choices[0].message.content
# Out:
# '두 카페의 차이점을 설명해 드리겠습니다.\n\n1. **첫 번째 카페**:\n   - **디자인 및 분위기**: 클래식하고 따뜻한 느낌의 인테리어. 나무와 가죽 소재가 주로 사용되며, 따뜻한 조명과 아늑함을 강조합니다.\n   - **좌석 배치**: 단순하고 실용적인 테이블과 의자로 구성되어 있으며, 주로 소규모의 테이블들입니다.\n   - **분위기**: 비교적 조용하고 친근한 분위기입니다.\n\n2. **두 번째 카페**:\n   - **디자인 및 분위기**: 현대적이고 세련된 인테리어. 대형 디지털 디스플레이와 화려한 조명이 있으며, 대리석 소재가 눈에 띕니다.\n   - **좌석 배치**: 다양한 형태의 고급스러운 소파와 의자가 배치되어 있으며, 넓고 개방적인 공간입니다.\n   - **분위기**: 고급스럽고 활기찬 분위기입니다.\n\n이 두 공간은 각기 다른 인테리어 스타일과 분위기를 제공합니다. 첫 번째 카페는 편안하고 친근한 분위기라면, 두 번째 카페는 현대적이고 고급스러운 환경을 제공합니다.'

# %%
oecd_rnd_2021_base64 = encode_image("./image/oecd_rnd_2021_large.png")
oecd_rnd_2022_base64 = encode_image('./image/oecd_rnd_2022.png')

messages = [
    {
        "role" : "user",
        "content" : [
            {"type" : "text", "text" : "첫 번째는 2021년 데이터이고, 두 번째는 2022년 데이터입니다. 이 데이터에 대해 설명해 주세요. 어떤 변화가 있었나요? 한국을 중심으로 설명해 주세요."},
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : f"data:image/jpeg;base64,{oecd_rnd_2021_base64}"
                }
            },
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : f"data:image/jpeg;base64,{oecd_rnd_2022_base64}"
                }
            }
        ]
    }
]

response = client.chat.completions.create(
    model='gpt-4o',
    messages=messages
)

response.choices[0].message.content
# Out:
# '2021년과 2022년 데이터를 비교하면, 한국의 연구개발비(R&D 지출)와 GDP 대비 연구개발비 비중의 변화를 확인할 수 있습니다.\n\n- **연구개발비**: \n  - 2021년에는 89,282백만 달러였으며, 2022년에는 91,013백만 달러로 증가했습니다.\n  \n- **GDP 대비 연구개발비 비중**: \n  - 2021년에는 4.93%였고, 2022년에는 약간 감소한 4.81%를 기록했습니다.\n\n전체적으로 한국은 연구개발비가 증가했지만, GDP 대비 연구개발비 비중은 약간 감소한 것으로 나타났습니다. 이는 경제 성장 속도가 연구개발비 증가 속도보다 조금 더 빠르거나, 다른 요인이 작용했을 가능성을 시사합니다. \n\n다른 국가들과 비교했을 때, 한국의 R&D 지출과 GDP 대비 비중은 여전히 높은 수준을 유지하고 있습니다.'

# %%
oecd_rnd_2021_base64 = encode_image("./image/oecd_rnd_2021_medium.png")
oecd_rnd_2022_base64 = encode_image('./image/oecd_rnd_2022.png')

messages = [
    {
        "role" : "user",
        "content" : [
            {"type" : "text", "text" : "첫 번째는 2021년 데이터이고, 두 번째는 2022년 데이터입니다. 이 데이터에 대해 설명해 주세요. 어떤 변화가 있었나요? 한국을 중심으로 설명해 주세요."},
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : f"data:image/jpeg;base64,{oecd_rnd_2021_base64}"
                }
            },
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : f"data:image/jpeg;base64,{oecd_rnd_2022_base64}"
                }
            }
        ]
    }
]

response = client.chat.completions.create(
    model='gpt-4o',
    messages=messages
)

response.choices[0].message.content
# Out:
# '두 그래프는 2021년과 2022년을 기준으로 한 국가별 연구개발비(R&D)와 GDP 대비 연구개발비 비중을 보여주고 있습니다.\n\n**2021년 데이터:**\n- 한국의 연구개발비는 121,739백만 달러로, GDP 대비 연구개발비 비중은 4.93%입니다.\n- 한국은 세계적으로 높은 연구개발비 비중을 가지고 있습니다.\n\n**2022년 데이터:**\n- 한국의 연구개발비는 133,867백만 달러로 증가했습니다.\n- GDP 대비 연구개발비 비중은 4.93%에서 5.21%로 상승했습니다.\n\n**변화 요약:**\n- 한국의 연구개발비가 12,128백만 달러 증가했습니다.\n- GDP 대비 연구개발비 비중도 상승하여, 한국의 연구개발 투자가 계속해서 강화되고 있음을 보여줍니다.\n\n이러한 증가는 한국의 지속적인 연구개발 투자 강화 노력을 반영하는 것으로 보입니다.'
