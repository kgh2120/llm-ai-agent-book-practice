# %%
# %pip install pyannote.audio
# %pip install numpy==1.26
# Out:
# Requirement already satisfied: pyannote.audio in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (3.3.2)
# Requirement already satisfied: asteroid-filterbanks>=0.4 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (0.4.0)
# Requirement already satisfied: einops>=0.6.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (0.8.1)
# Requirement already satisfied: huggingface-hub>=0.13.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (0.32.4)
# Requirement already satisfied: lightning>=2.0.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (2.5.1.post0)
# Requirement already satisfied: omegaconf<3.0,>=2.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (2.3.0)
# Requirement already satisfied: pyannote.core>=5.0.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (5.0.0)
# Requirement already satisfied: pyannote.database>=5.0.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (5.1.3)
# Requirement already satisfied: pyannote.metrics>=3.2 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (3.2.1)
# Requirement already satisfied: pyannote.pipeline>=3.0.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (3.0.1)
# Requirement already satisfied: pytorch-metric-learning>=2.1.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (2.8.1)
# Requirement already satisfied: rich>=12.0.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (14.0.0)
# Requirement already satisfied: semver>=3.0.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (3.0.4)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (0.13.1)
# Requirement already satisfied: speechbrain>=1.0.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (1.0.3)
# Requirement already satisfied: tensorboardX>=2.6 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (2.6.2.2)
# Requirement already satisfied: torch>=2.0.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (2.5.1+cu121)
# Requirement already satisfied: torch-audiomentations>=0.11.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (0.12.0)
# Requirement already satisfied: torchaudio>=2.2.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (2.5.1+cu121)
# Requirement already satisfied: torchmetrics>=0.11.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.audio) (1.7.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from omegaconf<3.0,>=2.1->pyannote.audio) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from omegaconf<3.0,>=2.1->pyannote.audio) (6.0.2)
# Requirement already satisfied: numpy in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from asteroid-filterbanks>=0.4->pyannote.audio) (1.26.0)
# Requirement already satisfied: typing-extensions in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from asteroid-filterbanks>=0.4->pyannote.audio) (4.14.0)
# Requirement already satisfied: filelock in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (24.2)
# Requirement already satisfied: requests in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (4.67.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from lightning>=2.0.1->pyannote.audio) (0.14.3)
# Requirement already satisfied: pytorch-lightning in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from lightning>=2.0.1->pyannote.audio) (2.5.1.post0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (3.12.7)
# Requirement already satisfied: setuptools in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from lightning-utilities<2.0,>=0.10.0->lightning>=2.0.1->pyannote.audio) (80.9.0)
# Requirement already satisfied: networkx in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from torch>=2.0.0->pyannote.audio) (3.5)
# Requirement already satisfied: jinja2 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from torch>=2.0.0->pyannote.audio) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from torch>=2.0.0->pyannote.audio) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from sympy==1.13.1->torch>=2.0.0->pyannote.audio) (1.3.0)
# Requirement already satisfied: colorama in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.13.0->pyannote.audio) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.20.0)
# Requirement already satisfied: idna>=2.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (3.10)
# Requirement already satisfied: sortedcontainers>=2.0.4 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.core>=5.0.0->pyannote.audio) (2.4.0)
# Requirement already satisfied: scipy>=1.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.core>=5.0.0->pyannote.audio) (1.15.3)
# Requirement already satisfied: pandas>=0.19 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.database>=5.0.1->pyannote.audio) (2.2.3)
# Requirement already satisfied: typer>=0.12.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.database>=5.0.1->pyannote.audio) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote.audio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote.audio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote.audio) (2025.2)
# Requirement already satisfied: scikit-learn>=0.17.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.metrics>=3.2->pyannote.audio) (1.6.1)
# Requirement already satisfied: docopt>=0.6.2 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.metrics>=3.2->pyannote.audio) (0.6.2)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.metrics>=3.2->pyannote.audio) (0.9.0)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.metrics>=3.2->pyannote.audio) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (3.2.3)
# Requirement already satisfied: optuna>=3.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from pyannote.pipeline>=3.0.1->pyannote.audio) (4.3.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (1.16.1)
# Requirement already satisfied: colorlog in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (2.0.41)
# Requirement already satisfied: Mako in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from alembic>=1.5.0->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (1.3.10)
# Requirement already satisfied: six>=1.5 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pyannote.database>=5.0.1->pyannote.audio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from rich>=12.0.0->pyannote.audio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from rich>=12.0.0->pyannote.audio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote.audio) (0.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from scikit-learn>=0.17.1->pyannote.metrics>=3.2->pyannote.audio) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from scikit-learn>=0.17.1->pyannote.metrics>=3.2->pyannote.audio) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from soundfile>=0.12.1->pyannote.audio) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->pyannote.audio) (2.22)
# Requirement already satisfied: hyperpyyaml in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from speechbrain>=1.0.0->pyannote.audio) (1.2.2)
# Requirement already satisfied: sentencepiece in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from speechbrain>=1.0.0->pyannote.audio) (0.2.0)
# Requirement already satisfied: greenlet>=1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from sqlalchemy>=1.4.2->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (3.2.2)
# Requirement already satisfied: protobuf>=3.20 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from tensorboardX>=2.6->pyannote.audio) (6.31.1)
# Requirement already satisfied: julius<0.3,>=0.2.3 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from torch-audiomentations>=0.11.0->pyannote.audio) (0.2.7)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from torch-audiomentations>=0.11.0->pyannote.audio) (1.2.5)
# Requirement already satisfied: primePy>=1.3 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.11.0->pyannote.audio) (1.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote.audio) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote.audio) (1.5.4)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from hyperpyyaml->speechbrain>=1.0.0->pyannote.audio) (0.18.12)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain>=1.0.0->pyannote.audio) (0.2.12)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from jinja2->torch>=2.0.0->pyannote.audio) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy==1.26 in c:\users\kyoohyun\desktop\llm-practice\venv\lib\site-packages (1.26.0)

# %%
from dotenv import load_dotenv
import os
import torch
# instantiate the pipeline
from pyannote.audio import Pipeline


load_dotenv()
hugging_face_access_token = os.getenv('HUGGING_FACE_TOKEN')

pipeline = Pipeline.from_pretrained(
  "pyannote/speaker-diarization-3.1",
  use_auth_token=hugging_face_access_token)

if torch.cuda.is_available():
    pipeline.to(torch.device("cuda"))
    print("cuda 사용이 가능합니다.")
else:
    print("쿠다 못씀 ㅋㅋ")


# run the pipeline on an audio file
diarization = pipeline("./audio/싼기타_비싼기타.mp3")

# dump the diarization output to disk using RTTM format
with open("싼기타_비싼기타.rttm", "w", encoding='utf-8') as rttm:
    diarization.write_rttm(rttm)
# Out:
# 쿠다 못씀 ㅋㅋ
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 23
#      19     print("쿠다 못씀 ㅋㅋ")
#      22 # run the pipeline on an audio file
# ---> 23 diarization = pipeline("./audio/싼기타_비싼기타.mp3")
#      25 # dump the diarization output to disk using RTTM format
#      26 with open("싼기타_비싼기타.rttm", "w", encoding='utf-8') as rttm:
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\pyannote\audio\core\pipeline.py:327, in Pipeline.__call__(self, file, **kwargs)
#     324 if hasattr(self, "preprocessors"):
#     325     file = ProtocolFile(file, lazy=self.preprocessors)
# --> 327 return self.apply(file, **kwargs)
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\pyannote\audio\pipelines\speaker_diarization.py:478, in SpeakerDiarization.apply(self, file, num_speakers, min_speakers, max_speakers, return_embeddings, hook)
#     470 hook = self.setup_hook(file, hook=hook)
#     472 num_speakers, min_speakers, max_speakers = self.set_num_speakers(
#     473     num_speakers=num_speakers,
#     474     min_speakers=min_speakers,
#     475     max_speakers=max_speakers,
#     476 )
# --> 478 segmentations = self.get_segmentations(file, hook=hook)
#     479 hook("segmentation", segmentations)
#     480 #   shape: (num_chunks, num_frames, local_num_speakers)
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\pyannote\audio\pipelines\speaker_diarization.py:224, in SpeakerDiarization.get_segmentations(self, file, hook)
#     222         file[self.CACHED_SEGMENTATION] = segmentations
#     223 else:
# --> 224     segmentations: SlidingWindowFeature = self._segmentation(file, hook=hook)
#     226 return segmentations
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\pyannote\audio\core\inference.py:421, in Inference.__call__(self, file, hook)
#     418 waveform, sample_rate = self.model.audio(file)
#     420 if self.window == "sliding":
# --> 421     return self.slide(waveform, sample_rate, hook=hook)
#     423 outputs: Union[np.ndarray, Tuple[np.ndarray]] = self.infer(waveform[None])
#     425 def __first_sample(outputs: np.ndarray, **kwargs) -> np.ndarray:
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\pyannote\audio\core\inference.py:313, in Inference.slide(self, waveform, sample_rate, hook)
#     310 for c in np.arange(0, num_chunks, self.batch_size):
#     311     batch: torch.Tensor = chunks[c : c + self.batch_size]
# --> 313     batch_outputs: Union[np.ndarray, Tuple[np.ndarray]] = self.infer(batch)
#     315     _ = map_with_specifications(
#     316         self.model.specifications, __append_batch, outputs, batch_outputs
#     317     )
#     319     if hook is not None:
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\pyannote\audio\core\inference.py:215, in Inference.infer(self, chunks)
#     213 with torch.inference_mode():
#     214     try:
# --> 215         outputs = self.model(chunks.to(self.device))
#     216     except RuntimeError as exception:
#     217         if is_oom_error(exception):
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\pyannote\audio\models\segmentation\PyanNet.py:223, in PyanNet.forward(self, waveforms)
#     211 def forward(self, waveforms: torch.Tensor) -> torch.Tensor:
#     212     """Pass forward
#     213
#     214     Parameters
#    (...)    220     scores : (batch, frame, classes)
#     221     """
# --> 223     outputs = self.sincnet(waveforms)
#     225     if self.hparams.lstm["monolithic"]:
#     226         outputs, _ = self.lstm(
#     227             rearrange(outputs, "batch feature frame -> batch frame feature")
#     228         )
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\pyannote\audio\models\blocks\sincnet.py:176, in SincNet.forward(self, waveforms)
#     171 outputs = self.wav_norm1d(waveforms)
#     173 for c, (conv1d, pool1d, norm1d) in enumerate(
#     174     zip(self.conv1d, self.pool1d, self.norm1d)
#     175 ):
# --> 176     outputs = conv1d(outputs)
#     178     # https://github.com/mravanelli/SincNet/issues/4
#     179     if c == 0:
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\torch\nn\modules\conv.py:375, in Conv1d.forward(self, input)
#     374 def forward(self, input: Tensor) -> Tensor:
# --> 375     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\kyoohyun\Desktop\llm-practice\venv\Lib\site-packages\torch\nn\modules\conv.py:370, in Conv1d._conv_forward(self, input, weight, bias)
#     358 if self.padding_mode != "zeros":
#     359     return F.conv1d(
#     360         F.pad(
#     361             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    368         self.groups,
#     369     )
# --> 370 return F.conv1d(
#     371     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     372 )
#
# KeyboardInterrupt:

# %%
import pandas as pd
rttm_path = './싼기타_비싼기타.rttm'

df_rttm = pd.read_csv(
    rttm_path,
    sep=' ',
    header=None,
    names=["type", "file", "chnl", "start", "duration", "C1", "C2", "speaker_id", "C3", "C4"]
)

display(df_rttm)
# Out:
#        type      file  chnl    start  duration  C1  C2  speaker_id  C3  C4  \
# 0   SPEAKER  싼기타_비싼기타     1    0.993     5.805 NaN NaN  SPEAKER_01 NaN NaN
# 1   SPEAKER  싼기타_비싼기타     1    7.405     3.983 NaN NaN  SPEAKER_01 NaN NaN
# 2   SPEAKER  싼기타_비싼기타     1   11.759     4.927 NaN NaN  SPEAKER_01 NaN NaN
# 3   SPEAKER  싼기타_비싼기타     1   17.210    10.665 NaN NaN  SPEAKER_01 NaN NaN
# 4   SPEAKER  싼기타_비싼기타     1   28.668     1.536 NaN NaN  SPEAKER_01 NaN NaN
# ..      ...       ...   ...      ...       ...  ..  ..         ...  ..  ..
# 83  SPEAKER  싼기타_비싼기타     1  414.481     2.970 NaN NaN  SPEAKER_00 NaN NaN
# 84  SPEAKER  싼기타_비싼기타     1  417.755     3.476 NaN NaN  SPEAKER_01 NaN NaN
# 85  SPEAKER  싼기타_비싼기타     1  423.644     0.776 NaN NaN  SPEAKER_00 NaN NaN
# 86  SPEAKER  싼기타_비싼기타     1  424.741     3.527 NaN NaN  SPEAKER_00 NaN NaN
# 87  SPEAKER  싼기타_비싼기타     1  428.504     0.844 NaN NaN  SPEAKER_00 NaN NaN
#
#     end
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# ..  ...
# 83  NaN
# 84  NaN
# 85  NaN
# 86  NaN
# 87  NaN
#
# [88 rows x 11 columns]

# %%
df_rttm['end'] = df_rttm['start'] + df_rttm['duration']

display(df_rttm)
# Out:
#        type      file  chnl    start  duration  C1  C2  speaker_id  C3  C4  \
# 0   SPEAKER  싼기타_비싼기타     1    0.993     5.805 NaN NaN  SPEAKER_01 NaN NaN
# 1   SPEAKER  싼기타_비싼기타     1    7.405     3.983 NaN NaN  SPEAKER_01 NaN NaN
# 2   SPEAKER  싼기타_비싼기타     1   11.759     4.927 NaN NaN  SPEAKER_01 NaN NaN
# 3   SPEAKER  싼기타_비싼기타     1   17.210    10.665 NaN NaN  SPEAKER_01 NaN NaN
# 4   SPEAKER  싼기타_비싼기타     1   28.668     1.536 NaN NaN  SPEAKER_01 NaN NaN
# ..      ...       ...   ...      ...       ...  ..  ..         ...  ..  ..
# 83  SPEAKER  싼기타_비싼기타     1  414.481     2.970 NaN NaN  SPEAKER_00 NaN NaN
# 84  SPEAKER  싼기타_비싼기타     1  417.755     3.476 NaN NaN  SPEAKER_01 NaN NaN
# 85  SPEAKER  싼기타_비싼기타     1  423.644     0.776 NaN NaN  SPEAKER_00 NaN NaN
# 86  SPEAKER  싼기타_비싼기타     1  424.741     3.527 NaN NaN  SPEAKER_00 NaN NaN
# 87  SPEAKER  싼기타_비싼기타     1  428.504     0.844 NaN NaN  SPEAKER_00 NaN NaN
#
#         end
# 0     6.798
# 1    11.388
# 2    16.686
# 3    27.875
# 4    30.204
# ..      ...
# 83  417.451
# 84  421.231
# 85  424.420
# 86  428.268
# 87  429.348
#
# [88 rows x 11 columns]

# %%
df_rttm["number"] = None
df_rttm.at[0,"number"] = 0

display(df_rttm)
# Out:
#        type      file  chnl    start  duration  C1  C2  speaker_id  C3  C4  \
# 0   SPEAKER  싼기타_비싼기타     1    0.993     5.805 NaN NaN  SPEAKER_01 NaN NaN
# 1   SPEAKER  싼기타_비싼기타     1    7.405     3.983 NaN NaN  SPEAKER_01 NaN NaN
# 2   SPEAKER  싼기타_비싼기타     1   11.759     4.927 NaN NaN  SPEAKER_01 NaN NaN
# 3   SPEAKER  싼기타_비싼기타     1   17.210    10.665 NaN NaN  SPEAKER_01 NaN NaN
# 4   SPEAKER  싼기타_비싼기타     1   28.668     1.536 NaN NaN  SPEAKER_01 NaN NaN
# ..      ...       ...   ...      ...       ...  ..  ..         ...  ..  ..
# 83  SPEAKER  싼기타_비싼기타     1  414.481     2.970 NaN NaN  SPEAKER_00 NaN NaN
# 84  SPEAKER  싼기타_비싼기타     1  417.755     3.476 NaN NaN  SPEAKER_01 NaN NaN
# 85  SPEAKER  싼기타_비싼기타     1  423.644     0.776 NaN NaN  SPEAKER_00 NaN NaN
# 86  SPEAKER  싼기타_비싼기타     1  424.741     3.527 NaN NaN  SPEAKER_00 NaN NaN
# 87  SPEAKER  싼기타_비싼기타     1  428.504     0.844 NaN NaN  SPEAKER_00 NaN NaN
#
#         end number
# 0     6.798      0
# 1    11.388   None
# 2    16.686   None
# 3    27.875   None
# 4    30.204   None
# ..      ...    ...
# 83  417.451   None
# 84  421.231   None
# 85  424.420   None
# 86  428.268   None
# 87  429.348   None
#
# [88 rows x 12 columns]

# %%
for i in range(1, len(df_rttm)):
    if df_rttm.at[i, "speaker_id"] != df_rttm.at[i-1, "speaker_id"]:
        df_rttm.at[i, "number"] = df_rttm.at[i-1, "number"] + 1
    else:
        df_rttm.at[i, "number"] = df_rttm.at[i-1, "number"]
display(df_rttm.head(10))
# Out:
#       type      file  chnl   start  duration  C1  C2  speaker_id  C3  C4  \
# 0  SPEAKER  싼기타_비싼기타     1   0.993     5.805 NaN NaN  SPEAKER_01 NaN NaN
# 1  SPEAKER  싼기타_비싼기타     1   7.405     3.983 NaN NaN  SPEAKER_01 NaN NaN
# 2  SPEAKER  싼기타_비싼기타     1  11.759     4.927 NaN NaN  SPEAKER_01 NaN NaN
# 3  SPEAKER  싼기타_비싼기타     1  17.210    10.665 NaN NaN  SPEAKER_01 NaN NaN
# 4  SPEAKER  싼기타_비싼기타     1  28.668     1.536 NaN NaN  SPEAKER_01 NaN NaN
# 5  SPEAKER  싼기타_비싼기타     1  32.414     0.759 NaN NaN  SPEAKER_00 NaN NaN
# 6  SPEAKER  싼기타_비싼기타     1  33.545     3.561 NaN NaN  SPEAKER_00 NaN NaN
# 7  SPEAKER  싼기타_비싼기타     1  37.628     3.763 NaN NaN  SPEAKER_00 NaN NaN
# 8  SPEAKER  싼기타_비싼기타     1  41.611     1.097 NaN NaN  SPEAKER_00 NaN NaN
# 9  SPEAKER  싼기타_비싼기타     1  41.645     0.810 NaN NaN  SPEAKER_01 NaN NaN
#
#       end number
# 0   6.798      0
# 1  11.388      0
# 2  16.686      0
# 3  27.875      0
# 4  30.204      0
# 5  33.173      1
# 6  37.106      1
# 7  41.391      1
# 8  42.708      1
# 9  42.455      2

# %%
df_rttm_grouped = df_rttm.groupby("number").agg(
    start=pd.NamedAgg(column='start', aggfunc='min'),
    end=pd.NamedAgg(column='end', aggfunc='max'),
    speaker_id=pd.NamedAgg(column='speaker_id', aggfunc='first')
)

display(df_rttm_grouped)
# Out:
#           start      end  speaker_id
# number
# 0         0.993   30.204  SPEAKER_01
# 1        32.414   42.708  SPEAKER_00
# 2        41.645   44.024  SPEAKER_01
# 3        45.813   67.109  SPEAKER_00
# 4        67.227   82.786  SPEAKER_01
# 5        84.659  102.564  SPEAKER_00
# 6       103.492  117.532  SPEAKER_01
# 7       119.759  138.676  SPEAKER_00
# 8       139.351  168.967  SPEAKER_01
# 9       170.907  192.321  SPEAKER_00
# 10      192.322  193.689  SPEAKER_01
# 11      192.760  193.503  SPEAKER_00
# 12      193.823  216.571  SPEAKER_01
# 13      218.579  238.120  SPEAKER_00
# 14      238.120  238.677  SPEAKER_01
# 15      238.188  239.352  SPEAKER_00
# 16      239.858  240.651  SPEAKER_01
# 17      240.297  241.006  SPEAKER_00
# 18      241.040  251.334  SPEAKER_01
# 19      253.696  271.550  SPEAKER_00
# 20      272.140  304.557  SPEAKER_01
# 21      306.970  326.022  SPEAKER_00
# 22      326.360  335.472  SPEAKER_01
# 23      337.548  355.925  SPEAKER_00
# 24      356.245  363.974  SPEAKER_01
# 25      365.982  381.423  SPEAKER_00
# 26      382.165  383.734  SPEAKER_01
# 27      385.726  397.184  SPEAKER_00
# 28      397.623  399.108  SPEAKER_01
# 29      401.437  406.601  SPEAKER_00
# 30      407.326  408.338  SPEAKER_01
# 31      410.093  417.451  SPEAKER_00
# 32      417.755  421.231  SPEAKER_01
# 33      423.644  429.348  SPEAKER_00

# %%
df_rttm_grouped['duration'] = df_rttm_grouped['end'] - df_rttm_grouped['start']
df_rttm_grouped = df_rttm_grouped.reset_index(drop=True)
display(df_rttm_grouped)
# Out:
#       start      end  speaker_id  duration
# 0     0.993   30.204  SPEAKER_01    29.211
# 1    32.414   42.708  SPEAKER_00    10.294
# 2    41.645   44.024  SPEAKER_01     2.379
# 3    45.813   67.109  SPEAKER_00    21.296
# 4    67.227   82.786  SPEAKER_01    15.559
# 5    84.659  102.564  SPEAKER_00    17.905
# 6   103.492  117.532  SPEAKER_01    14.040
# 7   119.759  138.676  SPEAKER_00    18.917
# 8   139.351  168.967  SPEAKER_01    29.616
# 9   170.907  192.321  SPEAKER_00    21.414
# 10  192.322  193.689  SPEAKER_01     1.367
# 11  192.760  193.503  SPEAKER_00     0.743
# 12  193.823  216.571  SPEAKER_01    22.748
# 13  218.579  238.120  SPEAKER_00    19.541
# 14  238.120  238.677  SPEAKER_01     0.557
# 15  238.188  239.352  SPEAKER_00     1.164
# 16  239.858  240.651  SPEAKER_01     0.793
# 17  240.297  241.006  SPEAKER_00     0.709
# 18  241.040  251.334  SPEAKER_01    10.294
# 19  253.696  271.550  SPEAKER_00    17.854
# 20  272.140  304.557  SPEAKER_01    32.417
# 21  306.970  326.022  SPEAKER_00    19.052
# 22  326.360  335.472  SPEAKER_01     9.112
# 23  337.548  355.925  SPEAKER_00    18.377
# 24  356.245  363.974  SPEAKER_01     7.729
# 25  365.982  381.423  SPEAKER_00    15.441
# 26  382.165  383.734  SPEAKER_01     1.569
# 27  385.726  397.184  SPEAKER_00    11.458
# 28  397.623  399.108  SPEAKER_01     1.485
# 29  401.437  406.601  SPEAKER_00     5.164
# 30  407.326  408.338  SPEAKER_01     1.012
# 31  410.093  417.451  SPEAKER_00     7.358
# 32  417.755  421.231  SPEAKER_01     3.476
# 33  423.644  429.348  SPEAKER_00     5.704

# %%
df_rttm_grouped.to_csv(
    "./싼기타_비싼기타_rttm.csv",
    sep=',',
    index=False
)
