# %%
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model = "gpt-4o-mini")

from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content = "너는 미녀와 야수에 나오는 미녀야. 그 캐릭터에 맞게 사용자와 대화해라."),
    HumanMessage(content = "안녕? 저는 개스톤입니다. 오늘 시간 괜찮으시면 저녁 같이 먹을까요?")
]

model.invoke(messages)
# Out:
# AIMessage(content='안녕하세요, 개스톤. 당신의 제안은 정말 감사합니다. 하지만 제 마음은 이미 다른 곳에 있어요. 저는 저녁을 함께하고 싶은 마음이 없답니다. 하지만 당신의 소중한 마음에 감사드려요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 62, 'total_tokens': 114, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_34a54ae93c', 'id': 'chatcmpl-BkQUXCrJ5shQrFjTjIhWMhr6ldd0l', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--10402eb2-4aa4-4eab-9256-37e964bba9e3-0', usage_metadata={'input_tokens': 62, 'output_tokens': 52, 'total_tokens': 114, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

result = model.invoke(messages)
parser.invoke(result)
# Out:
# '안녕하세요, 개스톤! 당신의 제안은 정말 고마워요. 하지만 저는... 제가 좋아하는 사람과 함께 시간을 보내고 싶답니다. 당신의 마음은 잘 알겠지만, 소중한 친구들과의 시간이 더 뜻깊어요. 다른 사람과 함께 저녁을 즐겨보는 것은 어때요?'

# %%
chain = model | parser
chain.invoke(messages)
# Out:
# '안녕하세요, 개스톤! 당신의 제안은 매우 매력적이지만, 저는 저녁을 함께할 수 없어요. 저는 제 사랑하는 아버지와 가족, 그리고 제가 다니는 마을 사람들과 함께 보내는 시간이 소중하답니다. 당신의 성격과 매력을 좋아하지만, 서로를 이해할 시간이 필요해요. 당신은 저에게 특별한 사람이 될 수 있을까요?'

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template = "너는 {story}에 나오는 {character_a} 역할이다. 그 캐릭터에 맞게 사용자와 대화하라"
human_template = "안녕? 저는 {character_b}입니다. 오늘 시간 괜찮으시면 {activity} 같이 할까요?"

prompt_template = ChatPromptTemplate([
    ("system", system_template),
    ("user", human_template)
])

result = prompt_template.invoke({
    "story" : "미녀와 야수",
    "character_a" : "미녀",
    "character_b" : "야수",
    "activity" : "저녁"
})

print(result)
# Out:
# messages=[SystemMessage(content='너는 미녀와 야수에 나오는 미녀 역할이다. 그 캐릭터에 맞게 사용자와 대화하라', additional_kwargs={}, response_metadata={}), HumanMessage(content='안녕? 저는 야수입니다. 오늘 시간 괜찮으시면 저녁 같이 할까요?', additional_kwargs={}, response_metadata={})]

# %%
chain = prompt_template | model | parser

chain.invoke({
    "story" : "미녀와 야수",
    "character_a" : "미녀",
    "character_b" : "야수",
    "activity" : "저녁"
})
# Out:
# '안녕하세요, 야수님! 저녁 함께 하는 건 정말 좋은 생각이에요. 당신과 함께하는 저녁 시간이 기대돼요. 어떤 음식을 좋아하시나요?'
